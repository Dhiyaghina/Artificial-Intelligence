# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhiyaghina/Artificial-Intelligence/blob/main/Klasifikasi_Breast_Cancer_dengan_Decission_Tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Alasan Pembuatan Model
# Saya mengambil dataset [Breast Cancer Wisconsin](https://www.kaggle.com/datasets/uciml/breast-cancer-wisconsin-data) dari Kaggle dengan jumlah data yaitu 569 yang digunakan untuk mengklasifikasikan penyakit kanker payudara jinak (benign) dan kanker payudara ganas (malignant).

# %% [markdown]
# ## Mengimport Library

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Membaca Dataset

# %%
# Membaca file csv
df = pd.read_csv('data.csv')
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %% [markdown]
# ## Melakukan EDA

# %%
# Melihat info dataset
df.info()

# Melihat jumlah data
row_count = df.shape[0]
print('Total data : ', row_count)

# Melihat info dataset pada 5 baris pertama
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
# Melihat info dataset pada 5 baris terakhir
df.tail()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 564  926424         M        21.56         22.39          142.00     1479.0
# 565  926682         M        20.13         28.25          131.20     1261.0
# 566  926954         M        16.60         28.08          108.30      858.1
# 567  927241         M        20.60         29.33          140.10     1265.0
# 568   92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
# ...

# %%
# Melihat jumlah nilai null
df.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %% [markdown]
# ## Melakukan Preprocessing

# %%
# Data cleaning menghilangkan kolom yang tidak penting
df.drop('id',axis=1,inplace=True)

# Menghapus kolom Unnamed
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

# Memisahkan atribut dan label
X = df[['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean', 'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean', 'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se', 'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se', 'fractal_dimension_se', 'radius_worst', 'texture_worst', 'perimeter_worst', 'area_worst', 'smoothness_worst', 'compactness_worst', 'concavity_worst', 'concave points_worst', 'symmetry_worst', 'fractal_dimension_worst']]
y = df['diagnosis']

# %% [markdown]
# ## Membagi Data Latih dan Data Uji

# %%
# Menggunakan rasio 3:2 (60% Train dan 40% Test) karena jumlah data < 800
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=123)

# %% [markdown]
# ## Train Model

# %%
# Membuat model Decision Tree
tree_model = DecisionTreeClassifier()

# Melatih model
tree_model = tree_model.fit(X_train, y_train)

# %% [markdown]
# ## Evaluasi Model

# %%
y_pred = tree_model.predict(X_test)

score = round(accuracy_score(y_pred, y_test), 3)

print('Nilai Akurasi: ', score)
# Out:
# Nilai Akurasi:  0.939

# %% [markdown]
# ## Buat 5 Data Dummy

# %%
# Create dummy data manually
dummy_data = {
   'radius_mean': [18.0, 13.0, 18.69, 14.78, 12.36],
    'texture_mean': [10.38, 19.31, 21.25, 23.94, 21.8],
    'perimeter_mean': [122.8, 82.61, 130.0, 97.4, 79.78],
    'area_mean': [1001, 527.2, 1203, 668.3, 466.1],
    'smoothness_mean': [0.1184, 0.0806, 0.1096, 0.1172, 0.08772],
    'compactness_mean': [0.2776, 0.03789, 0.1599, 0.1479, 0.09445],
    'concavity_mean': [0.3001, 0.000692, 0.1974, 0.1267, 0.06015],
    'concave points_mean': [0.1471, 0.004167, 0.1279, 0.09029, 0.03745],
    'symmetry_mean': [0.2419, 0.1819, 0.2069, 0.1953, 0.193],
    'fractal_dimension_mean': [0.07871, 0.05501, 0.05999, 0.06654, 0.06404],
    'radius_se': [1.095, 0.404, 0.7456, 0.3577, 0.2978],
    'texture_se': [0.9053, 1.214, 0.7869, 1.281, 1.502],
    'perimeter_se': [8.589, 2.595, 4.585, 2.45, 2.203],
    'area_se': [153.4, 32.96, 94.03, 35.24, 20.95],
    'smoothness_se': [0.006399, 0.007491, 0.00615, 0.006703, 0.007112],
    'compactness_se': [0.04904, 0.008593, 0.04006, 0.0231, 0.02493],
    'concavity_se': [0.05373, 0.000692, 0.03832, 0.02315, 0.02703],
    'concave points_se': [0.01587, 0.004167, 0.02058, 0.01184, 0.01293],
    'symmetry_se': [0.03003, 0.0219, 0.0225, 0.019, 0.01958],
    'fractal_dimension_se': [0.006193, 0.00299, 0.004571, 0.003224, 0.004463],
    'radius_worst': [25.38, 14.23, 23.57, 17.31, 13.83],
    'texture_worst': [17.33, 22.25, 25.53, 33.39, 30.5],
    'perimeter_worst': [184.6, 90.24, 152.5, 114.6, 91.46],
    'area_worst': [2019, 624.1, 1709, 925.1, 574.7],
    'smoothness_worst': [0.1622, 0.1021, 0.1444, 0.1648, 0.1304],
    'compactness_worst': [0.6656, 0.06191, 0.4245, 0.3416, 0.2463],
    'concavity_worst': [0.7119, 0.001845, 0.4504, 0.3024, 0.2434],
    'concave points_worst': [0.2654, 0.01111, 0.243, 0.1614, 0.1205],
    'symmetry_worst': [0.4601, 0.2439, 0.3613, 0.3321, 0.2972],
    'fractal_dimension_worst': [0.1189, 0.06289, 0.08758, 0.08911, 0.09261]
}

# Buat DataFrame untuk X
dummy_X = pd.DataFrame(dummy_data)

# Buat dummy data untuk y (diagnosis)
dummy_y = pd.Series(['M', 'B', 'M', 'M', 'B'])

# %% [markdown]
# ## Prediksi 5 Data Dummy

# %%
# prediksi model dengan tree_model.predict([[radius_mean, texture_mean, perimeter_mean, area_mean, smoothness_mean, compactness_mean, concavity_mean, concave points_mean, symmetry_mean, fractal_dimension_mean, radius_se, texture_se, perimeter_se, area_se, smoothness_se, compactness_se, concavity_se, concave points_se, symmetry_se, fractal_dimension_se, radius_worst, texture_worst, perimeter_worst, area_worst, smoothness_worst, compactness_worst, concavity_worst, concave points_worst, symmetry_worst, fractal_dimension_worst]])
transposed_data = [list(row) for row in zip(*dummy_data.values())]
for index, item in enumerate(transposed_data):
  print('Data Dummy', index , ':', tree_model.predict([item])[0])
# Out:
# Data Dummy 0 : M
# Data Dummy 1 : B
# Data Dummy 2 : M
# Data Dummy 3 : M
# Data Dummy 4 : B
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# ...

# %% [markdown]
# ## Uji Akurasi Data Dummy

# %%
y_pred = tree_model.predict(dummy_X)

score = round(accuracy_score(y_pred, dummy_y), 3)

print('Nilai Akurasi Data Dummy: ', score)
# Out:
# Nilai Akurasi Data Dummy:  1.0

# %% [markdown]
# ## Kesimpulan Uji Akurasi

# %% [markdown]
# Nilai akurasi pada data test adalah **93.4%** menunjukkan bahwa model memiliki performa yang baik dalam mengklasifikasikan data yang tidak pernah dilihat sebelumnya. Meskipun tidak mencapai tingkat keakuratan sempurna, tetapi hasil yang tinggi tersebut menunjukkan bahwa model memiliki kemampuan yang baik dalam memprediksi label kelas.
#
# Sementara itu, hasil evaluasi model decision tree dari 5 data dummy sebesar **100%** menunjukkan bahwa model berhasil mengklasifikasikan data baru dengan sempurna. Ini menunjukkan bahwa model mampu mengklasifikasi dengan sangat baik antara fitur dan label kelas pada data yang tidak pernah dilihat sebelumnya.
#
# Kedua hasil evaluasi tersebut menunjukkan bahwa model decision tree memiliki kinerja yang sangat baik dalam mengklasifikasikan data, dengan tingkat keakuratan yang tinggi baik pada data test maupun data baru.
